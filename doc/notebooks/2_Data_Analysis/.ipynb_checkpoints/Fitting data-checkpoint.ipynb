# %%
# %load_ext autoreload
# %matplotlib nbagg
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Data Fitting
#
# The purpose of this part ....

# %% [markdown]
# ## Introduction with a simple tow points line equation

# %% [markdown]
# Let's annalyse how to determine the simple equation of a line ($y=ax+b$) kowing tow points of the line.

# %%
y=np.array([-1,2])
x=np.array([.5,3])
x,y
# Out:
# (array([ 0.5,  3. ]), array([-1,  2]))

# %%
fig = plt.figure()
plt.plot(x,y,'o')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Todertermine the $a$ and $b$ coefficents, we have to solve the following system :
#
# $y_0=ax_0+b$
#
# $y_1=ax_1+b$
#
#
# Lets reorgenized a bit this system :
#
# $ b + ax_0 = y_0 $
#
# $ b + ax_1 = y_1 $
#
# Its konw easy to write it as a linear systeme :
#
# $
# \begin{bmatrix}
# 1 & x_0 \\
# 1 & x_1
# \end{bmatrix}
# .
# \begin{bmatrix}
# b \\
# a
# \end{bmatrix}
# =
# \begin{bmatrix}
# y_0 \\
# y_1
# \end{bmatrix}
# $
#
# Therfore the $a$ and $b$ coefficents can be determine :
#
# $
# \begin{bmatrix}
# b \\
# a
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 & x_0 \\
# 1 & x_1
# \end{bmatrix}^{-1}
# .
# \begin{bmatrix}
# y_0 \\
# y_1
# \end{bmatrix}
# $

# %% [markdown]
# ### Let's do this with python

# %%
# definition of the involved matrix :
A=np.array([[1, x[0]],[1,x[1]]])
B=np.array([y[0],y[1]]).T
B
# Out:
# array([-1,  2])

# %%
# Inversion of the systeme
coef=np.matmul(np.linalg.inv(A),B)
coef
a = coef[1]
b = coef[0]

# %%
# draw the obtained line
N = 10
xmin, xmax = 0., 4
xi = np.linspace(xmin, xmax, N)
yi = a * xi + b

# %%
fig = plt.figure()
plt.plot(x,y,'o')
plt.plot(xi,yi,'r')
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **Question 2**: What is the ratio between male and female involved in accident ? Show results in a graphical way.

# %%
df.sexe.value_counts(normalize=True)

# %%
fig = plt.figure()
df.sexe.value_counts(normalize=True).plot.pie(labels=['Homme', 'Femme'], colors= ['r', 'g'], autopct='%.2f')

# %% [markdown]
# **Question 3**: What is the ratio between male and female involved in accident considering only the dirver  ? Show results in a graphical way.

# %%
df.sexe[df.place==1] .value_counts(normalize=True)

# %% [markdown]
# **Question 4**: What is the ratio between male and female involved in accident considering all victim expceped the driver  ? Show results in a graphical way.

# %%
df.sexe[df.place!=1] .value_counts(normalize=True)

# %% [markdown]
# **Question 5**: What is the ratio between accidents taking place during day, night, and tranision day/night ? Show results in a graphical way.

# %%
dlum = df["lum"].value_counts(normalize=True)
dlum = dlum.sort_index()

# %%
dlum[3] = dlum[3:5].sum()
dlum

# %%
val = dlum[1:3].values
explode = (0.1, 0.1, .1)  # only "explode" the 2nd slice (i.e. 'Hogs')
labels = "day", "transition", "night"
fig1, ax1 = plt.subplots()
ax1.pie(val, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# **Question 5**: Propose a graphical repesentation to higlight the geographical position on each accident which have take place on the metropolitan territory.

# %%
# Step by step
dfp = df[df.gps=='M']
dfp = dfp[['lat','long']]
dfp = dfp[(dfp.long!=0.0) & (dfp.lat!=0.0)]
dfp.head()

# %%
plt.figure()
dfp.plot.scatter(x='long', y='lat',s=1);

# %%
# in one step
plt.figure()
df[(df.long!=0.0) & (df.lat!=0.0) & (df.gps=='M')].plot.scatter(x='long', y='lat',s=.5)

# %% [markdown]
# **Question 5**: Propose a graphical repesentation to higlight the age of the involved victim. (You should first compute the age ot each personne)

# %%
df=df.assign(age=2016.-dfu.an_nais)
nb_bin=df.age.max().astype(np.int)

# %%
plt.figure()
df['age'].hist(bins=nb_bin)
plt.show()

# %%
plt.figure()
df[(df.long!=0.0) & (df.lat!=0.0) & (df.gps=='M')].plot.scatter(x='long', y='lat',c='age',s=.5)
